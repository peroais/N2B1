# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
links = pd.read_csv('/content/links.csv')

# %%
movies = pd.read_csv('/content/movies.csv')

# %%
ratings = pd.read_csv('/content/ratings.csv')

# %%
tags = pd.read_csv('/content/tags.csv')

# %%
links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   imdbId   9742 non-null   int64
#  2   tmdbId   9734 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 228.5 KB

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Código do Usuário  3683 non-null   int64
#  1   Código do Filme    3683 non-null   int64
#  2   Característica     3683 non-null   object
#  3   Data               3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB

# %%
movies.columns = ['Código do Filme','Título','Gênero']

# %%
movies.head(9743)
# Out:
#       Código do Filme                                     Título  \
# 0                   1                           Toy Story (1995)
# 1                   2                             Jumanji (1995)
# 2                   3                    Grumpier Old Men (1995)
# 3                   4                   Waiting to Exhale (1995)
# 4                   5         Father of the Bride Part II (1995)
# ...               ...                                        ...
# 9737           193581  Black Butler: Book of the Atlantic (2017)
# 9738           193583               No Game No Life: Zero (2017)
# 9739           193585                               Flint (2017)
# 9740           193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741           193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            Gênero
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# ...

# %%
ratings.columns = ['Código do Usuário','Código do Filme','Avaliação','Data']

# %%
ratings.head(100837)
# Out:
#         Código do Usuário  Código do Filme  Avaliação        Data
# 0                       1                1        4.0   964982703
# 1                       1                3        4.0   964981247
# 2                       1                6        4.0   964982224
# 3                       1               47        5.0   964983815
# 4                       1               50        5.0   964982931
# ...                   ...              ...        ...         ...
# 100831                610           166534        4.0  1493848402
# 100832                610           168248        5.0  1493850091
# 100833                610           168250        5.0  1494273047
# 100834                610           168252        5.0  1493846352
# 100835                610           170875        3.0  1493846415
#
# [100836 rows x 4 columns]
# ...

# %%
tags.columns = ['Código do Usuário','Código do Filme','Característica','Data']

# %%
tags.head(3684)
# Out:
#       Código do Usuário  Código do Filme    Característica        Data
# 0                     2            60756             funny  1445714994
# 1                     2            60756   Highly quotable  1445714996
# 2                     2            60756      will ferrell  1445714992
# 3                     2            89774      Boxing story  1445715207
# 4                     2            89774               MMA  1445715200
# ...                 ...              ...               ...         ...
# 3678                606             7382         for katie  1171234019
# 3679                606             7936           austere  1173392334
# 3680                610             3265            gun fu  1493843984
# 3681                610             3265  heroic bloodshed  1493843978
# 3682                610           168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
df = ratings[['Código do Filme', 'Avaliação']]

# %%
df
# Out:
#         Código do Filme  Avaliação
# 0                     1        4.0
# 1                     3        4.0
# 2                     6        4.0
# 3                    47        5.0
# 4                    50        5.0
# ...                 ...        ...
# 100831           166534        4.0
# 100832           168248        5.0
# 100833           168250        5.0
# 100834           168252        5.0
# 100835           170875        3.0
#
# [100836 rows x 2 columns]
# ...

# %%
media_avaliacoes_por_filme = ratings.groupby('Código do Filme')['Avaliação'].mean().apply(lambda x: round(x, 3))

# %%
tabela_media_avaliacoes = pd.DataFrame(media_avaliacoes_por_filme).reset_index()
tabela_media_avaliacoes.columns = ['Código do Filme', 'Média das Avaliações']

# %%
print(media_avaliacoes_por_filme)
# Out:
# Código do Filme
# 1         3.921
# 2         3.432
# 3         3.260
# 4         2.357
# 5         3.071
#           ...
# 193581    4.000
# 193583    3.500
# 193585    3.500
# 193587    3.500
# 193609    4.000
# Name: Avaliação, Length: 9724, dtype: float64

# %%
media_avaliacoes_por_filme.head(9724)
# Out:
# Código do Filme
# 1         3.921
# 2         3.432
# 3         3.260
# 4         2.357
# 5         3.071
#           ...
# 193581    4.000
# 193583    3.500
# 193585    3.500
# 193587    3.500
# 193609    4.000
# Name: Avaliação, Length: 9724, dtype: float64

# %%
display(tabela_media_avaliacoes.head(9724))
# Out:
#       Código do Filme  Média das Avaliações
# 0                   1                 3.921
# 1                   2                 3.432
# 2                   3                 3.260
# 3                   4                 2.357
# 4                   5                 3.071
# ...               ...                   ...
# 9719           193581                 4.000
# 9720           193583                 3.500
# 9721           193585                 3.500
# 9722           193587                 3.500
# 9723           193609                 4.000
#
# [9724 rows x 2 columns]

# %%
df = ratings[['Código do Usuário', 'Avaliação']]

# %%
df
# Out:
#         Código do Usuário  Avaliação
# 0                       1        4.0
# 1                       1        4.0
# 2                       1        4.0
# 3                       1        5.0
# 4                       1        5.0
# ...                   ...        ...
# 100831                610        4.0
# 100832                610        5.0
# 100833                610        5.0
# 100834                610        5.0
# 100835                610        3.0
#
# [100836 rows x 2 columns]
# ...

# %%
contagem_avaliacoes_por_usuario = ratings.groupby('Código do Usuário')['Avaliação'].count()

# %%
tabela_contagem_avaliacoes = pd.DataFrame(contagem_avaliacoes_por_usuario).reset_index()

# %%
tabela_contagem_avaliacoes.columns = ['Código do Usuário', 'Número de Avaliações']

# %%
display(tabela_contagem_avaliacoes)
# Out:
#      Código do Usuário  Número de Avaliações
# 0                    1                   232
# 1                    2                    29
# 2                    3                    39
# 3                    4                   216
# 4                    5                    44
# ..                 ...                   ...
# 605                606                  1115
# 606                607                   187
# 607                608                   831
# 608                609                    37
# 609                610                  1302
#
# [610 rows x 2 columns]

# %%
df = tags[['Código do Usuário', 'Característica']]

# %%
df
# Out:
#       Código do Usuário    Característica
# 0                     2             funny
# 1                     2   Highly quotable
# 2                     2      will ferrell
# 3                     2      Boxing story
# 4                     2               MMA
# ...                 ...               ...
# 3678                606         for katie
# 3679                606           austere
# 3680                610            gun fu
# 3681                610  heroic bloodshed
# 3682                610  Heroic Bloodshed
#
# [3683 rows x 2 columns]

# %%
contagem_caracteristicas_por_usuario = tags.groupby('Código do Usuário')['Característica'].count()

# %%
tabela_contagem_caracteristicas = pd.DataFrame(contagem_caracteristicas_por_usuario).reset_index()

# %%
tabela_contagem_caracteristicas.columns = ['Código do Usuário', 'Característica']

# %%
display(tabela_contagem_caracteristicas)
# Out:
#     Código do Usuário  Característica
# 0                   2               9
# 1                   7               1
# 2                  18              16
# 3                  21               4
# 4                  49               3
# 5                  62             370
# 6                  63               2
# 7                  76               2
# 8                 103               5
# 9                 106               2
# 10                112               3
# 11                119              14
# 12                125              48
# 13                132               4
# 14                138               2
# 15                161               1
# 16                166               6
# 17                167               1
# 18                177               3
# 19                184              35
# 20                193              20
# 21                205               3
# 22                226               3
# 23                256               2
# ...

# %%
df = pd.DataFrame(tags['Característica'])

# %%
df
# Out:
#         Característica
# 0                funny
# 1      Highly quotable
# 2         will ferrell
# 3         Boxing story
# 4                  MMA
# ...                ...
# 3678         for katie
# 3679           austere
# 3680            gun fu
# 3681  heroic bloodshed
# 3682  Heroic Bloodshed
#
# [3683 rows x 1 columns]

# %%
contagem_linhas_duplicadas = df.groupby(df.columns.tolist()).size().reset_index(name='Quantidade')

# %%
print(contagem_linhas_duplicadas)
# Out:
#                                  Característica  Quantidade
# 0                                       "artsy"           1
# 1     06 Oscar Nominated Best Movie - Animation           3
# 2                                         1900s           1
# 3                                         1920s           2
# 4                                         1950s           2
# ...                                         ...         ...
# 1584                                        wry           1
# 1585                                younger men           1
# 1586                                     zither           1
# 1587                                  zoe kazan           1
# 1588                                    zombies           6
#
# [1589 rows x 2 columns]

# %%
contagem_linhas_duplicadas.head(1589)
# Out:
#                                  Característica  Quantidade
# 0                                       "artsy"           1
# 1     06 Oscar Nominated Best Movie - Animation           3
# 2                                         1900s           1
# 3                                         1920s           2
# 4                                         1950s           2
# ...                                         ...         ...
# 1584                                        wry           1
# 1585                                younger men           1
# 1586                                     zither           1
# 1587                                  zoe kazan           1
# 1588                                    zombies           6
#
# [1589 rows x 2 columns]

# %%
df = ratings[['Data', 'Avaliação']]

# %%
df
# Out:
#               Data  Avaliação
# 0        964982703        4.0
# 1        964981247        4.0
# 2        964982224        4.0
# 3        964983815        5.0
# 4        964982931        5.0
# ...            ...        ...
# 100831  1493848402        4.0
# 100832  1493850091        5.0
# 100833  1494273047        5.0
# 100834  1493846352        5.0
# 100835  1493846415        3.0
#
# [100836 rows x 2 columns]
# ...

# %%
contagem_avaliacoes_por_data = ratings.groupby('Data')['Código do Filme'].count()

# %%
tabela_contagem_avaliacoes = pd.DataFrame(contagem_avaliacoes_por_data).reset_index()

# %%
tabela_contagem_avaliacoes.columns = ['Data', 'Número de Avaliações']

# %%
display(tabela_contagem_avaliacoes)
# Out:
#              Data  Número de Avaliações
# 0       828124615                    20
# 1       828124616                    37
# 2       828124762                     1
# 3       829322340                     9
# 4       829759809                    21
# ...           ...                   ...
# 85038  1537674927                     1
# 85039  1537674946                     1
# 85040  1537757040                     1
# 85041  1537757059                     1
# 85042  1537799250                     1
#
# [85043 rows x 2 columns]
# ...
